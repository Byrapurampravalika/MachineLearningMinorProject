# %%
import pandas as pd

# %%
df=pd.read_csv("/content/DataCoSupplyChainDataset.csv",engine='python')

# %%
df
# Out:
#           Type  ...   Shipping Mode
# 0        DEBIT  ...  Standard Class
# 1     TRANSFER  ...  Standard Class
# 2         CASH  ...  Standard Class
# 3        DEBIT  ...  Standard Class
# 4      PAYMENT  ...  Standard Class
# ...        ...  ...             ...
# 7997      CASH  ...  Standard Class
# 7998      CASH  ...  Standard Class
# 7999      CASH  ...  Standard Class
# 8000      CASH  ...  Standard Class
# 8001      CASH  ...            None
#
# [8002 rows x 53 columns]

# %%
#Performing EDA

# %%
df.head()
# Out:
#        Type  ...   Shipping Mode
# 0     DEBIT  ...  Standard Class
# 1  TRANSFER  ...  Standard Class
# 2      CASH  ...  Standard Class
# 3     DEBIT  ...  Standard Class
# 4   PAYMENT  ...  Standard Class
#
# [5 rows x 53 columns]

# %%
df.tail()
# Out:
#       Type  Days for shipping (real)  ...  shipping date (DateOrders)   Shipping Mode
# 7997  CASH                         2  ...             6/25/2017 16:36  Standard Class
# 7998  CASH                         6  ...             6/26/2017 16:25  Standard Class
# 7999  CASH                         5  ...             7/13/2015 13:45  Standard Class
# 8000  CASH                         3  ...              6/20/2015 0:17  Standard Class
# 8001  CASH                         5  ...                        None            None
#
# [5 rows x 53 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8002 entries, 0 to 8001
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Type                           8002 non-null   object
#  1   Days for shipping (real)       8002 non-null   int64
#  2   Days for shipment (scheduled)  8002 non-null   int64
#  3   Benefit per order              8002 non-null   float64
#  4   Sales per customer             8002 non-null   float64
#  5   Delivery Status                8002 non-null   object
#  6   Late_delivery_risk             8002 non-null   int64
#  7   Category Id                    8002 non-null   int64
#  8   Category Name                  8002 non-null   object
#  9   Customer City                  8002 non-null   object
#  10  Customer Country               8002 non-null   object
#  11  Customer Email                 8002 non-null   object
# ...

# %%
df.shape
# Out:
# (8002, 53)

# %%
df.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Delivery Status',
#        'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Email', 'Customer Fname', 'Customer Id',
#        'Customer Lname', 'Customer Password', 'Customer Segment',
#        'Customer State', 'Customer Street', 'Customer Zipcode',
#        'Department Id', 'Department Name', 'Latitude', 'Longitude', 'Market',
#        'Order City', 'Order Country', 'Order Customer Id',
#        'order date (DateOrders)', 'Order Id', 'Order Item Cardprod Id',
#        'Order Item Discount', 'Order Item Discount Rate', 'Order Item Id',
#        'Order Item Product Price', 'Order Item Profit Ratio',
#        'Order Item Quantity', 'Sales', 'Order Item Total',
#        'Order Profit Per Order', 'Order Region', 'Order State', 'Order Status',
# ...

# %%
df.describe()
# Out:
#        Days for shipping (real)  ...  Product Status
# count               8002.000000  ...          8001.0
# mean                   3.719195  ...             0.0
# std                    1.520679  ...             0.0
# min                    0.000000  ...             0.0
# 25%                    2.000000  ...             0.0
# 50%                    4.000000  ...             0.0
# 75%                    5.000000  ...             0.0
# max                    6.000000  ...             0.0
#
# [8 rows x 29 columns]

# %%
# cleaning the data

# %%
df.isnull()
# Out:
#        Type  ...  Shipping Mode
# 0     False  ...          False
# 1     False  ...          False
# 2     False  ...          False
# 3     False  ...          False
# 4     False  ...          False
# ...     ...  ...            ...
# 7997  False  ...          False
# 7998  False  ...          False
# 7999  False  ...          False
# 8000  False  ...          False
# 8001  False  ...           True
#
# [8002 rows x 53 columns]

# %%
df.isnull().any()
# Out:
# Type                             False
# Days for shipping (real)         False
# Days for shipment (scheduled)    False
# Benefit per order                False
# Sales per customer               False
# Delivery Status                  False
# Late_delivery_risk               False
# Category Id                      False
# Category Name                    False
# Customer City                    False
# Customer Country                 False
# Customer Email                   False
# Customer Fname                   False
# Customer Id                      False
# Customer Lname                   False
# Customer Password                False
# Customer Segment                 False
# Customer State                   False
# Customer Street                  False
# Customer Zipcode                 False
# Department Id                    False
# Department Name                  False
# Latitude                         False
# Longitude                        False
# ...

# %%
df.isnull().sum()
# Out:
# Type                                0
# Days for shipping (real)            0
# Days for shipment (scheduled)       0
# Benefit per order                   0
# Sales per customer                  0
# Delivery Status                     0
# Late_delivery_risk                  0
# Category Id                         0
# Category Name                       0
# Customer City                       0
# Customer Country                    0
# Customer Email                      0
# Customer Fname                      0
# Customer Id                         0
# Customer Lname                      0
# Customer Password                   0
# Customer Segment                    0
# Customer State                      0
# Customer Street                     0
# Customer Zipcode                    0
# Department Id                       0
# Department Name                     0
# Latitude                            0
# Longitude                           0
# Market                              0
# ...

# %%
df.drop('Product Description',axis='columns',inplace=True)

# %%
df
# Out:
#           Type  ...   Shipping Mode
# 0        DEBIT  ...  Standard Class
# 1     TRANSFER  ...  Standard Class
# 2         CASH  ...  Standard Class
# 3        DEBIT  ...  Standard Class
# 4      PAYMENT  ...  Standard Class
# ...        ...  ...             ...
# 7997      CASH  ...  Standard Class
# 7998      CASH  ...  Standard Class
# 7999      CASH  ...  Standard Class
# 8000      CASH  ...  Standard Class
# 8001      CASH  ...            None
#
# [8002 rows x 52 columns]

# %%
df.drop("Order Zipcode",axis='columns',inplace=True)

# %%
df
# Out:
#           Type  ...   Shipping Mode
# 0        DEBIT  ...  Standard Class
# 1     TRANSFER  ...  Standard Class
# 2         CASH  ...  Standard Class
# 3        DEBIT  ...  Standard Class
# 4      PAYMENT  ...  Standard Class
# ...        ...  ...             ...
# 7997      CASH  ...  Standard Class
# 7998      CASH  ...  Standard Class
# 7999      CASH  ...  Standard Class
# 8000      CASH  ...  Standard Class
# 8001      CASH  ...            None
#
# [8002 rows x 51 columns]

# %%
df=df.dropna()

# %%
df
# Out:
#           Type  ...   Shipping Mode
# 0        DEBIT  ...  Standard Class
# 1     TRANSFER  ...  Standard Class
# 2         CASH  ...  Standard Class
# 3        DEBIT  ...  Standard Class
# 4      PAYMENT  ...  Standard Class
# ...        ...  ...             ...
# 7996      CASH  ...  Standard Class
# 7997      CASH  ...  Standard Class
# 7998      CASH  ...  Standard Class
# 7999      CASH  ...  Standard Class
# 8000      CASH  ...  Standard Class
#
# [8001 rows x 51 columns]

# %%
duplicate_rows_df=df[df.duplicated()]

# %%
duplicate_rows_df
# Out:
# Empty DataFrame
# Columns: [Type, Days for shipping (real), Days for shipment (scheduled), Benefit per order, Sales per customer, Delivery Status, Late_delivery_risk, Category Id, Category Name, Customer City, Customer Country, Customer Email, Customer Fname, Customer Id, Customer Lname, Customer Password, Customer Segment, Customer State, Customer Street, Customer Zipcode, Department Id, Department Name, Latitude, Longitude, Market, Order City, Order Country, Order Customer Id, order date (DateOrders), Order Id, Order Item Cardprod Id, Order Item Discount, Order Item Discount Rate, Order Item Id, Order Item Product Price, Order Item Profit Ratio, Order Item Quantity, Sales, Order Item Total, Order Profit Per Order, Order Region, Order State, Order Status, Product Card Id, Product Category Id, Product Image, Product Name, Product Price, Product Status, shipping date (DateOrders), Shipping Mode]
# Index: []

# %%
df.boxplot(column=['Benefit per order'],figsize=(10,10))

# %%
df=df[df['Benefit per order']>-1500]

# %%
df
# Out:
#           Type  ...   Shipping Mode
# 0        DEBIT  ...  Standard Class
# 1     TRANSFER  ...  Standard Class
# 2         CASH  ...  Standard Class
# 3        DEBIT  ...  Standard Class
# 4      PAYMENT  ...  Standard Class
# ...        ...  ...             ...
# 7996      CASH  ...  Standard Class
# 7997      CASH  ...  Standard Class
# 7998      CASH  ...  Standard Class
# 7999      CASH  ...  Standard Class
# 8000      CASH  ...  Standard Class
#
# [8001 rows x 51 columns]

# %%
# QUESTIONS & ANSWERS

# %%
# 1.List all the cities and the respective number of pending orders in 'India' ?

# %%
df1=df[(df["Order Country"]=="India") & (df["Order Status"]=="PENDING")]

# %%
print(f"number of pending orders with respect to cities\n", df1[df1['Order Status']=="PENDING"]['Order City'].value_counts())
# Out:
# number of pending orders with respect to cities
#  Patna        3
# Bangalore    3
# Durg         2
# Kulti        1
# Pune         1
# Rohtak       1
# Bikaner      1
# Ranchi       1
# Guwahati     1
# Jaipur       1
# Jabalpur     1
# Gorakhpur    1
# Mumbai       1
# Fatehpur     1
# Imphal       1
# Lucknow      1
# Kota         1
# Faridabad    1
# Name: Order City, dtype: int64

# %%
df1[['Order City','Order Status']]
# Out:
#      Order City Order Status
# 1       Bikaner      PENDING
# 21     Jabalpur      PENDING
# 45    Bangalore      PENDING
# 46    Bangalore      PENDING
# 382        Pune      PENDING
# 708      Jaipur      PENDING
# 1024     Ranchi      PENDING
# 1031       Durg      PENDING
# 1054       Durg      PENDING
# 1161      Patna      PENDING
# 1163      Patna      PENDING
# 1167  Faridabad      PENDING
# 1236   Fatehpur      PENDING
# 1279       Kota      PENDING
# 1831   Guwahati      PENDING
# 2565     Rohtak      PENDING
# 2568     Mumbai      PENDING
# 2757      Kulti      PENDING
# 2759     Imphal      PENDING
# 5004  Gorakhpur      PENDING
# 5026  Bangalore      PENDING
# 5338      Patna      PENDING
# 5360    Lucknow      PENDING

# %%
# 2.Which country has the most suspected fraud ?

# %%
	highfraud=df[(df['Order Status']=='SUSPECTED_FRAUD') & (df['Type']=='TRANSFER')]

# %%
highfraud=highfraud[['Order Region']]

# %%
highfraud
# Out:
#          Order Region
# 10       Eastern Asia
# 24            Oceania
# 183        US Center
# 184      West of USA
# 185      West of USA
# ...               ...
# 5572       South Asia
# 5585       South Asia
# 5654  Central America
# 5668  Central America
# 5699  Northern Europe
#
# [185 rows x 1 columns]

# %%
valuecounts=highfraud['Order Region'].value_counts()

# %%
z1=valuecounts.to_dict()

# %%
highfraud['fraudcounts'] = highfraud['Order Region'].map(z1)

# %%
highfraud.sort_values('fraudcounts').tail(1)
# Out:
#          Order Region  fraudcounts
# 1007  Central America           28

# %%
	import matplotlib.pyplot as plt
	highfraud = df[(df['Order Status'] == 'SUSPECTED_FRAUD') & (df['Type'] == 'TRANSFER')]
	fraud=highfraud['Order Region'].value_counts().plot.pie(figsize=(24,12),startangle=180,autopct='%.1f')
	plt.title("Regions with Highest Fraud ",size=25,color='b')
	plt.ylabel(" ")
	fraud.axis('equal') 
	plt.show()

# %%
# 3.Which country has the most suspected fraud ?

# %%
	df["Order Item Discount"].max()
# Out:
# 375.0

# %%
dis=df.sort_values('Order Item Discount')

# %%
dis['Product Name'].tail(1)
# Out:
# 1594    Dell Laptop
# Name: Product Name, dtype: object

# %%
# 4.Which product(s) has/have the maximum discount ?

# %%
df['order_year']= pd.DatetimeIndex(df['order date (DateOrders)']).year

# %%
	df.head()
# Out:
#        Type  Days for shipping (real)  ...   Shipping Mode  order_year
# 0     DEBIT                         3  ...  Standard Class        2018
# 1  TRANSFER                         5  ...  Standard Class        2018
# 2      CASH                         4  ...  Standard Class        2018
# 3     DEBIT                         3  ...  Standard Class        2018
# 4   PAYMENT                         2  ...  Standard Class        2018
#
# [5 rows x 52 columns]

# %%
	df2=df[['order_year','Sales','Product Name']]

# %%
df2.head()
# Out:
#    order_year   Sales  Product Name
# 0        2018  327.75  Smart watch
# 1        2018  327.75  Smart watch
# 2        2018  327.75  Smart watch
# 3        2018  327.75  Smart watch
# 4        2018  327.75  Smart watch

# %%
c=df2[df2['Product Name'].str.contains('Nike')]

# %%
c.head()
# Out:
#     order_year       Sales                          Product Name
# 50        2016  100.000000  Nike Men's Dri-FIT Victory Golf Polo
# 52        2016  100.000000  Nike Men's Dri-FIT Victory Golf Polo
# 53        2016  100.000000  Nike Men's Dri-FIT Victory Golf Polo
# 54        2015  100.000000  Nike Men's Dri-FIT Victory Golf Polo
# 59        2016  299.970001     Nike Men's Free 5.0+ Running Shoe

# %%
c[['Sales','order_year','Product Name']].value_counts()
# Out:
# Sales       order_year  Product Name
# 129.990005  2016        Nike Men's CJ Elite 2 TD Football Cleat    385
#             2015        Nike Men's CJ Elite 2 TD Football Cleat    375
#             2017        Nike Men's CJ Elite 2 TD Football Cleat    213
# 250.000000  2015        Nike Men's Dri-FIT Victory Golf Polo       130
# 200.000000  2015        Nike Men's Dri-FIT Victory Golf Polo       117
#                                                                   ...
# 150.000000  2016        Nike Women's Tempo Shorts                    1
# 89.980003   2016        Nike Men's Comfort 2 Slide                   1
# 120.000000  2017        Nike Women's Tempo Shorts                    1
# 75.000000   2017        Nike Women's Legend V-Neck T-Shirt           1
# 499.950012  2017        Nike Men's Free TR 5.0 TB Training Shoe      1
# Length: 103, dtype: int64

# %%
c['Sales'].min()
# Out:
# 22.0

# %%
result_df=c[(c['Sales']==22.0) & c['order_year']]

# %%
result_df
# Out:
#       order_year  Sales                   Product Name
# 2571        2017   22.0  Nike Dri-FIT Crew Sock 6 Pack
# 2575        2017   22.0  Nike Dri-FIT Crew Sock 6 Pack
# 2576        2017   22.0  Nike Dri-FIT Crew Sock 6 Pack
# 2587        2017   22.0  Nike Dri-FIT Crew Sock 6 Pack
# 2591        2017   22.0  Nike Dri-FIT Crew Sock 6 Pack
# 2598        2017   22.0  Nike Dri-FIT Crew Sock 6 Pack
# 2601        2017   22.0  Nike Dri-FIT Crew Sock 6 Pack
# 2602        2017   22.0  Nike Dri-FIT Crew Sock 6 Pack
# 2754        2015   22.0  Nike Dri-FIT Crew Sock 6 Pack
# 2760        2015   22.0  Nike Dri-FIT Crew Sock 6 Pack
# 2765        2015   22.0  Nike Dri-FIT Crew Sock 6 Pack
# 2771        2015   22.0  Nike Dri-FIT Crew Sock 6 Pack
# 2772        2015   22.0  Nike Dri-FIT Crew Sock 6 Pack
# 2775        2015   22.0  Nike Dri-FIT Crew Sock 6 Pack
# 2786        2015   22.0  Nike Dri-FIT Crew Sock 6 Pack
# 2789        2015   22.0  Nike Dri-FIT Crew Sock 6 Pack
# ...

# %%
result_df[['order_year']].value_counts()
# Out:
# order_year
# 2015          24
# 2017           8
# dtype: int64

# %%
result_df[['order_year']].value_counts().min()
# Out:
# 8

# %%
import seaborn as sb

# %%
sb.set(rc={'figure.figsize':(35,12)})
sb.countplot(x='Sales',hue='order_year',data=c)

# %%
# 5.How many succesfully processed orders have days for shipping real(Real) > Days for shipment (Scheduled) ?

# %%
late_df=df[['Days for shipping (real)','Days for shipment (scheduled)','Order Status']]

# %%
late_df
# Out:
#       Days for shipping (real)  Days for shipment (scheduled)     Order Status
# 0                            3                              4         COMPLETE
# 1                            5                              4          PENDING
# 2                            4                              4           CLOSED
# 3                            3                              4         COMPLETE
# 4                            2                              4  PENDING_PAYMENT
# ...                        ...                            ...              ...
# 7996                         5                              4           CLOSED
# 7997                         2                              4           CLOSED
# 7998                         6                              4           CLOSED
# 7999                         5                              4           CLOSED
# 8000                         3                              4           CLOSED
#
# [8001 rows x 3 columns]

# %%
dfs=late_df[late_df['Order Status']=="COMPLETE"]

# %%
dfs
# Out:
#       Days for shipping (real)  Days for shipment (scheduled) Order Status
# 0                            3                              4     COMPLETE
# 3                            3                              4     COMPLETE
# 6                            2                              1     COMPLETE
# 13                           2                              1     COMPLETE
# 15                           2                              1     COMPLETE
# ...                        ...                            ...          ...
# 7640                         6                              2     COMPLETE
# 7641                         2                              2     COMPLETE
# 7642                         3                              2     COMPLETE
# 7643                         6                              2     COMPLETE
# 7644                         2                              2     COMPLETE
#
# [2716 rows x 3 columns]

# %%
p=dfs[(dfs['Days for shipping (real)'] > dfs['Days for shipment (scheduled)'])]

# %%
p
# Out:
#       Days for shipping (real)  Days for shipment (scheduled) Order Status
# 6                            2                              1     COMPLETE
# 13                           2                              1     COMPLETE
# 15                           2                              1     COMPLETE
# 18                           2                              1     COMPLETE
# 25                           6                              2     COMPLETE
# ...                        ...                            ...          ...
# 7636                         3                              2     COMPLETE
# 7638                         5                              2     COMPLETE
# 7640                         6                              2     COMPLETE
# 7642                         3                              2     COMPLETE
# 7643                         6                              2     COMPLETE
#
# [1603 rows x 3 columns]

# %%
p.value_counts()
# Out:
# Days for shipping (real)  Days for shipment (scheduled)  Order Status
# 6                         2                              COMPLETE        281
# 4                         2                              COMPLETE        279
# 5                         4                              COMPLETE        265
# 3                         2                              COMPLETE        263
# 6                         4                              COMPLETE        248
# 5                         2                              COMPLETE        201
# 2                         1                              COMPLETE         54
# 1                         0                              COMPLETE         12
# dtype: int64

# %%
p.shape
# Out:
# (1603, 3)

# %%
index=p.index
no_of_rows=len(index)
print(no_of_rows)
# Out:
# 1603
